# %%
import sys
import tqdm
sys.path.append('/usr/local/lib/python3.7/site-packages')
import json,nltk
import numpy as np
from nltk.tokenize import sent_tokenize
from collections import Counter
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from nltk.stem.porter import PorterStemmer
from nltk.stem.wordnet import WordNetLemmatizer
import re
import nltk
#nltk.download('stopwords')
#nltk.download('wordnet') 
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from nltk.tokenize import RegexpTokenizer
from nltk.stem.wordnet import WordNetLemmatizer
from sklearn.feature_extraction.text import CountVectorizer
import re
import copy

# %%
lem = WordNetLemmatizer()
stem = PorterStemmer()
word = "inversely"
stop_words = set(stopwords.words("english"))
new_words = ["using", "show", "result", "large", "also", "iv", "one", "two", "new", "previously", "shown"]
stop_words = stop_words.union(new_words)

# %% [markdown]
# ## Functions Definitions:

# %%
def get_cosine_sim(*strs): 
    vectors = [t for t in get_vectors(*strs)]
    return cosine_similarity(vectors)
    
def get_vectors(*strs):
    text = [t for t in strs]
    vectorizer = CountVectorizer(text)
    vectorizer.fit(text)
    return vectorizer.transform(text).toarray()

# %%
def get_single_keywords(text2):
    corpus = []
    
    #Remove punctuations
    text = re.sub('[^a-zA-Z]', ' ', text2)

    #Convert to lowercase
    text = text.lower()

    #remove tags
    text=re.sub("&lt;/?.*?&gt;"," &lt;&gt; ",text)

    # remove special characters and digits
    text=re.sub("(\\d|\\W)+"," ",text)

    ##Convert to list from string
    text = text.split()

    ##Stemming
    ps=PorterStemmer()
    #Lemmatisation
    lem = WordNetLemmatizer()
    text = [lem.lemmatize(word) for word in text if not word in  
            stop_words] 
    text = " ".join(text)
    corpus.append(text)
    cv=CountVectorizer(stop_words=stop_words, max_features=10000, ngram_range=(1,3))
    X=cv.fit_transform(corpus)
    keys = list(cv.vocabulary_.keys())
    keys2 = []
    for i in keys:
        if len(i.split(" ")) > 1:
            break
        keys2.append(i)
    return keys2

# %%
def get_cost_line(text):
    tokens = sent_tokenize(text)
    tokens.append("$300 shipped")
    tokens.append("$300 shipping")
    tokens.append("cost")
    tokens.append("about $450")
    tokens.append("asking $450")
    tokens.append("single $450")
    vecs = get_cosine_sim(*tokens)
    common_sents = []
    for j,evec in enumerate(vecs):
        if j == len(vecs) - 6:
            break
        if (evec[-1] != 0 and round(evec[-1]) != 1) or (evec[-2] != 0 and round(evec[-2]) != 1) or (evec[-3] != 0 and round(evec[-3]) != 1) or (evec[-4] != 0 and round(evec[-4]) != 1 or (evec[-5] != 0 and round(evec[-5]) != 1)):
            common_sents.append(tokens[j])
    return common_sents

# %%
def filter_price(money):
    irr = ["*","ft","/","+","lb","eating","1.0","0.1","hrs","g","-","in","year","yr","sq","mon","th","hours","nd","gal","x","foot","obo","prs"]
    if len(money) <=2:
        return False
    if money[0].isnumeric() == False:
        return False
    for i in irr:
        if money.find(i) >= 0:
#             print(money,i)
            return False      
    for i in range(1995,2019):
        if money.find(str(i)) >= 0:
            return False
    return True

# %%
def get_money_value(text):
    tags = nltk.pos_tag(nltk.word_tokenize(text))
    for j,i in enumerate(tags):
        if i[1] == '$':
            if tags[j+1][1] == 'CD':
                    return tags[j+1][0]
        if i[1] == 'CD' and i[0].isnumeric:
            if len(str(i[0]))>=2 and tags[j+1][0]!='%':
                return tags[j][0]
    return 0

# %% [markdown]
# ## Functional APIs

# %%
def load_json(name="zoo_data_n.json"):
    with open(name) as f:
        data = json.load(f)
    return data

# %%
def get_cleaned_data(data):
    data2 = copy.deepcopy(data)
    new_features = []
    j = 0
    fl = 0
    for i in tqdm.tqdm(data2['features']):
        money = 0 
        if fl == 0:
            fl = 1
            continue
        try:
            money_lines = get_cost_line(i['Description'])
        except:
            continue
        for j in money_lines:
            try:
                money = get_money_value(j)
            except:
                continue
            if money != 0:
                break
        if money == 0:
            continue
        else:
            try:
                keys = get_single_keywords(i['Description'])
            except:
                continue
            i.pop('Description',None)
            i['Price'] = money
            i['Keywords'] = keys
            valid = filter_price(money)
            if valid == False:
                continue
            new_features.append(i)
    return new_features

# %%
def dump_json(new_features,name='zoo_data_nf.json'):
    data_n={}
    data_n['type'] = 'FeatureCollection'
    data_n['name'] = 'Zoo'
    data_n['features'] = new_features
    with open(name, 'w') as f:
        json.dump(data_n, f)

# %% [markdown]
# ## Use Case:

# %%
data = load_json()
new_features = get_cleaned_data(data)
# Out:
# 100%|██████████| 87919/87919 [02:51<00:00, 511.21it/s]

# %%
new_features
# Out:
# [{'User_name': 'Red769',
#   'AD_name': 'Manokwari GTP',
#   'Date': '10-17-2019, 05:37 PM',
#   'Type_1': '> Reptile & Amphibian - Classifieds',
#   'Type_2': '> Snakes For Sale/Wanteds',
#   'Type_3': '> Arboreal Boas/Pythons',
#   'Sale_or_no': '[For Sale] Manokwari GTP',
#   'Price': '500',
#   'Keywords': ['owned',
#    'year',
#    'since',
#    'baby',
#    'great',
#    'eater',
#    'shed',
#    'well',
#    'asking',
#    'pick',
#    'hamburg',
#    'reptile',
#    'believe',
#    'male',
#    'going',
#    'probed',
#    'expert',
#    'sexing']},
#  {'User_name': 'Red769',
#   'AD_name': 'Manokwari GTP',
#   'Date': '10-17-2019, 05:37 PM',
#   'Type_1': '> Reptile & Amphibian - Classifieds',
#   'Type_2': '> Snakes For Sale/Wanteds',
#   'Type_3': '> Arboreal Boas/Pythons',
#   'Sale_or_no': '[For Sale] Manokwari GTP',
#   'Price': '500',
#   'Keywords': ['owned',
#    'year',
#    'since',
#    'baby',
#    'great',
#    'eater',
#    'shed',
#    'well',
#    'asking',
#    'pick',
#    'hamburg',
#    'reptile',
#    'believe',
#    'male',
#    'going',
#    'probed',
#    'expert',
#    'sexing']},
#  {'User_name': 'Dozerpush1437',
#   'AD_name': '2018 female Bonnie x Clyde Highlighter Jungle',
#   'Date': '11-03-2019, 11:49 PM',
#   'Type_1': '> Reptile & Amphibian - Classifieds',
#   'Type_2': '> Snakes For Sale/Wanteds',
#   'Type_3': '> Arboreal Boas/Pythons',
#   'Sale_or_no': '[For Sale] 2018 female Bonnie x Clyde Highlighter Jungle',
#   'Price': '450',
#   'Keywords': ['female',
#    'scott',
#    'zimmerman',
#    'bonnie',
#    'clyde',
#    'highlighter',
#    'pairing',
#    'soulglow',
#    'blood',
#    'side',
#    'princess',
#    'slam',
#    'frozen',
#    'thawed',
#    'rat',
#    'chill',
#    'dfw',
#    'would',
#    'really',
#    'prefer',
#    'local',
#    'sale',
#    'within',
#    'reasonable',
#    'driving',
#    'distance',
#    'possible',
#    'pm',
#    'interested',
#    'see',
#    'work',
#    'obo',
#    'st',
#    'couple',
#    'pic',
#    'offering',
#    'following',
#    'sire',
#    'dam']},
#  {'User_name': 'FBskateboarder',
#   'AD_name': 'Female Jungle Carpet Python',
#   'Date': '11-03-2019, 09:55 AM',
#   'Type_1': '> Reptile & Amphibian - Classifieds',
#   'Type_2': '> Snakes For Sale/Wanteds',
#   'Type_3': '> Arboreal Boas/Pythons',
#   'Sale_or_no': '[For Sale] Female Jungle Carpet Python',
#   'Price': '450',
#   'Keywords': ['offering',
#    'german',
#    'harris',
#    'line',
#    'female',
#    'sale',
#    'produced',
#    'david',
#    'haisten',
#    'shed',
#    'time',
#    'price',
#    'shipped']},
#  {'User_name': 'Ed Lilley',
#   'AD_name': '19 Pure Irian Jaya Axanthic female 19AXf3',
#   'Date': '10-09-2019, 08:01 PM',
#   'Type_1': '> Reptile & Amphibian - Classifieds',
#   'Type_2': '> Snakes For Sale/Wanteds',
#   'Type_3': '> Arboreal Boas/Pythons',
#   'Sale_or_no': '19 Pure Irian Jaya Axanthic female 19AXf3',
#   'Price': '750',
#   'Keywords': ['pure',
#    'irian',
#    'jaya',
#    'axanthic',
#    'female',
#    'feeding',
#    'mouse',
#    'hopper',
#    'produced',
#    'ij',
#    'male',
#    'bred',
#    'het',
#    'going',
#    'key',
#    'lot',
#    'project',
#    'great',
#    'animal',
#    'plus',
#    'shipping']},
#  {'User_name': 'Steve.Anderson',
#   'AD_name': 'Male Jungle Jag',
#   'Date': '10-30-2019, 08:23 PM',
#   'Type_1': '> Reptile & Amphibian - Classifieds',
#   'Type_2': '> Snakes For Sale/Wanteds',
#   'Type_3': '> Arboreal Boas/Pythons',
#   'Sale_or_no': '[For Sale] Male Jungle Jag',
#   'Price': '300',
#   'Keywords': ['male',
#    'born',
#    'june',
#    'healthy',
#    'feed',
#    'rat',
#    'message',
#    'info',
#    'picture',
#    'threethree',
#    'shipped']},
#  {'User_name': 'snakelax3',
#   'AD_name': 'Designer blueline x calico gtp ECJH-19-04 Priced lowered 850 shipped',
#   'Date': '10-28-2019, 02:51 PM',
#   'Type_1': '> Reptile & Amphibian - Classifieds',
#   'Type_2': '> Snakes For Sale/Wanteds',
#   'Type_3': '> Arboreal Boas/Pythons',
#   'Sale_or_no': '[For Sale] Designer blueline x calico gtp ECJH-19-04 Priced lowered 850 shipped',
#   'Price': '850',
#   'Keywords': ['time',
#    'releasing',
#    'offspring',
#    'calico',
#    'blueline',
#    'pairing',
#    'ecjh',
#    'date',
#    'birth',
#    'guy',
#    'pounding',
#    'pinky',
#    'gusto',
#    'meal',
#    'dam',
#    'tsk',
#    'artic',
#    'blue',
#    'tidbit',
#    'sire',
#    'produced',
#    'eric',
#    'bro',
#    'mandango',
#    'kelme',
#    'carpetman',
#    'queen',
#    'production',
#    'good',
#    'genetics',
#    'could',
#    'turn',
#    'great',
#    'info',
#    'check',
#    'posting',
#    'mvf',
#    'july',
#    'reason',
#    'let',
#    'put',
#    'link',
#    'asking',
#    'shipped',
#    'accept',
#    'paypal',
#    'located',
#    'san',
#    'diego',
#    'ca',
#    'reach',
#    'snakelax',
#    'gmail',
#    'com']},
#  {'User_name': 'Gangemiw',
#   'AD_name': 'Aru Green Tree Python Female 1',
#   'Date': '10-27-2019, 10:03 PM',
#   'Type_1': '> Reptile & Amphibian - Classifieds',
#   'Type_2': '> Snakes For Sale/Wanteds',
#   'Type_3': '> Arboreal Boas/Pythons',
#   'Sale_or_no': '[For Sale] Aru Green Tree Python Female 1',
#   'Price': '499.99',
#   'Keywords': ['snake',
#    'established',
#    'import',
#    'super',
#    'clean',
#    'taking',
#    'adult',
#    'mouse',
#    'tongs',
#    'issue',
#    'foot',
#    'plus',
#    'length',
#    'would',
#    'make',
#    'awesome',
#    'addition',
#    'anyones',
#    'group',
#    'want',
#    'bloodline',
#    'asking',
#    'shipped']},
#  {'User_name': 'crazyslushy',
#   'AD_name': 'Rough Scaled Pythons',
#   'Date': '10-25-2019, 12:55 PM',
#   'Type_1': '> Reptile & Amphibian - Classifieds',
#   'Type_2': '> Snakes For Sale/Wanteds',
#   'Type_3': '> Arboreal Boas/Pythons',
#   'Sale_or_no': '[For Sale] Rough Scaled Pythons',
#   'Price': '2800',
#   'Keywords': ['beautiful',
#    'rare',
#    'specie',
#    'eating',
#    'great',
#    'growing',
#    'quickly',
#    'plus',
#    'shipping',
#    'per',
#    'pair',
#    'message',
#    'text',
#    'question',
#    'five',
#    'six']},
#  {'User_name': 'mrdecay',
#   'AD_name': 'boelens/jungle x jungle python',
#   'Date': '09-09-2019, 11:45 PM',
#   'Type_1': '> Reptile & Amphibian - Classifieds',
#   'Type_2': '> Snakes For Sale/Wanteds',
#   'Type_3': '> Arboreal Boas/Pythons',
#   'Sale_or_no': '[For Sale] boelens/jungle x jungle python',
#   'Price': '400',
#   'Keywords': ['boelens',
#    'jungle',
#    'carpet',
#    'male',
#    'bred',
#    'female',
#    'pair',
#    'single',
#    'price',
#    'includes',
#    'shipping',
#    'airport',
#    'delta',
#    'text',
#    'jason']},
#  {'User_name': 'tsauls1',
#   'AD_name': '2019 USCBB Red Neo GTPs $900',
#   'Date': '10-18-2019, 11:00 AM',
#   'Type_1': '> Reptile & Amphibian - Classifieds',
#   'Type_2': '> Snakes For Sale/Wanteds',
#   'Type_3': '> Arboreal Boas/Pythons',
#   'Sale_or_no': '2019 USCBB Red Neo GTPs $900',
#   'Price': '900',
#   'Keywords': ['uscbb', 'red', 'neonate', 'available', 'plus', 'shipping']},
#  {'User_name': 'DayWalker',
#   'AD_name': '2019 Female Jungle carpet (1)',
#   'Date': '10-21-2019, 05:39 PM',
#   'Type_1': '> Reptile & Amphibian - Classifieds',
#   'Type_2': '> Snakes For Sale/Wanteds',
#   'Type_3': '> Arboreal Boas/Pythons',
#   'Sale_or_no': '2019 Female Jungle carpet (1)',
#   'Price': '300',
#   'Keywords': ['crazy',
#    'aberrant',
#    'pattern',
#    'girl',
#    'big',
#    'eating',
#    'rat',
#    'fuzzies',
#    'tongs',
#    'stellar',
#    'looking',
#    'parent',
#    'looker',
#    'shipped',
#    'email',
#    'ijlover',
#    'yahoo',
#    'com']},
#  {'User_name': 'Warf',
#   'AD_name': '2018 (F) Jungle Jag Carpet Python $200',
#   'Date': '10-09-2019, 06:58 PM',
#   'Type_1': '> Reptile & Amphibian - Classifieds',
#   'Type_2': '> Snakes For Sale/Wanteds',
#   'Type_3': '> Arboreal Boas/Pythons',
#   'Sale_or_no': '[For Sale] 2018 (F) Jungle Jag Carpet Python $200',
#   'Price': '200',
#   'Keywords': ['offering',
#    'beautiful',
#    'high',
#    'contrast',
#    'jungle',
#    'jag',
#    'gamma',
#    'female',
#    'carpet',
#    'python',
#    'plus',
#    'shipping',
#    'fantastic',
#    'eater',
#    'feeding',
#    'well',
#    'fuzzies',
#    'great',
#    'response',
#    'live',
#    'small',
#    'mouse',
#    'though',
#    'mainly',
#    'feed',
#    'unlike',
#    'young',
#    'incredibly',
#    'hand',
#    'tamed',
#    'yet',
#    'bite',
#    'even',
#    'strike',
#    'matter']},
#  {'User_name': 'Ed Lilley',
#   'AD_name': '19 Pure IJ AXANTHIC female 19AXF5',
#   'Date': '09-20-2019, 04:04 PM',
#   'Type_1': '> Reptile & Amphibian - Classifieds',
#   'Type_2': '> Snakes For Sale/Wanteds',
#   'Type_3': '> Arboreal Boas/Pythons',
#   'Sale_or_no': '19 Pure IJ AXANTHIC female 19AXF5',
#   'Price': '825',
#   'Keywords': ['pure',
#    'ij',
#    'axanthic',
#    'female',
#    'feeding',
#    'mouse',
#    'hopper',
#    'produced',
#    'male',
#    'bred',
#    'het',
#    'got',
#    'stripey',
#    'stuff',
#    'clutch',
#    'leaning',
#    'way',
#    'striped',
#    'axanthics',
#    'would',
#    'nice',
#    'going',
#    'key',
#    'lot',
#    'project',
#    'great',
#    'animal',
#    'plus',
#    'shipping']},
#  {'User_name': 'MartinR',
#   'AD_name': '2019 Male MBeach x Hamper Jungles',
#   'Date': '10-09-2019, 05:03 PM',
#   'Type_1': '> Reptile & Amphibian - Classifieds',
#   'Type_2': '> Snakes For Sale/Wanteds',
#   'Type_3': '> Arboreal Boas/Pythons',
#   'Sale_or_no': '[For Sale] 2019 Male MBeach x Hamper Jungles',
#   'Price': '450',
#   'Keywords': ['outstanding',
#    'male',
#    'mbeach',
#    'hamper',
#    'pairing',
#    'eating',
#    'rat',
#    'pink',
#    'without',
#    'hesitation',
#    'asking',
#    'shipped',
#    'please',
#    'mail',
#    'faster',
#    'response',
#    'thank']},
#  {'User_name': 'MartinR',
#   'AD_name': '2019 Male Lemke x Hamper Jungles',
#   'Date': '10-09-2019, 05:05 PM',
#   'Type_1': '> Reptile & Amphibian - Classifieds',
#   'Type_2': '> Snakes For Sale/Wanteds',
#   'Type_3': '> Arboreal Boas/Pythons',
#   'Sale_or_no': '[For Sale] 2019 Male Lemke x Hamper Jungles',
#   'Price': '450',
#   'Keywords': ['outstanding',
#    'male',
#    'lemke',
#    'hamper',
#    'pairing',
#    'eating',
#    'rat',
#    'pink',
#    'without',
#    'hesitation',
#    'asking',
#    'shipped',
#    'please',
#    'mail',
#    'faster',
#    'response',
#    'thank']},
#  {'User_name': 'Arcanine550',
#   'AD_name': '2015 0.1 Jungle Zebra',
#   'Date': '09-05-2019, 06:37 PM',
#   'Type_1': '> Reptile & Amphibian - Classifieds',
#   'Type_2': '> Snakes For Sale/Wanteds',
#   'Type_3': '> Arboreal Boas/Pythons',
#   'Sale_or_no': '2015 0.1 Jungle Zebra',
#   'Price': '500',
#   'Keywords': ['letting',
#    'go',
#    'female',
#    'zebra',
#    'sold',
#    'pure',
#    'jungle',
#    'absolute',
#    'sweetheart',
#    'never',
#    'struck',
#    'eats',
#    'anything',
#    'put',
#    'front',
#    'great',
#    'addition',
#    'collection',
#    'problem',
#    'breeding',
#    'upcoming',
#    'season',
#    'asking',
#    'obo',
#    'shipping']},
#  {'User_name': 'DayWalker',
#   'AD_name': '2019 Male Zebra',
#   'Date': '10-06-2019, 09:41 AM',
#   'Type_1': '> Reptile & Amphibian - Classifieds',
#   'Type_2': '> Snakes For Sale/Wanteds',
#   'Type_3': '> Arboreal Boas/Pythons',
#   'Sale_or_no': '2019 Male Zebra',
#   'Price': '300',
#   'Keywords': ['awesome',
#    'looking',
#    'zebra',
#    'ready',
#    'start',
#    'twin',
#    'bit',
#    'small',
#    'still',
#    'eats',
#    'rat',
#    'pinky',
#    'problem',
#    'included',
#    'picture',
#    'parent',
#    'ad',
#    'shipped',
#    'email',
#    'ijlover',
#    'yahoo',
#    'com']},
#  {'User_name': 'jharty86',
#   'AD_name': '2018 Female Ocelot Jaguar Carpet Python',
#   'Date': '10-01-2019, 12:56 PM',
#   'Type_1': '> Reptile & Amphibian - Classifieds',
#   'Type_2': '> Snakes For Sale/Wanteds',
#   'Type_3': '> Arboreal Boas/Pythons',
#   'Sale_or_no': '[For Sale] 2018 Female Ocelot Jaguar Carpet Python',
#   'Price': '500',
#   'Keywords': ['got',
#    'back',
#    'january',
#    'roughly',
#    'strong',
#    'feeding',
#    'response',
#    'feed',
#    'small',
#    'rat',
#    'asking',
#    'shipped',
#    'text',
#    'detail']},
#  {'User_name': 'vicbevpines',
#   'AD_name': '2019 Jungle Carpet pythons Lazik/Vpi',
#   'Date': '09-30-2019, 12:36 PM',
#   'Type_1': '> Reptile & Amphibian - Classifieds',
#   'Type_2': '> Snakes For Sale/Wanteds',
#   'Type_3': '> Arboreal Boas/Pythons',
#   'Sale_or_no': '2019 Jungle Carpet pythons Lazik/Vpi',
#   'Price': '200',
#   'Keywords': ['jungle',
#    'carpet',
#    'python',
#    'available',
#    'pure',
#    'lazik',
#    'vpi',
#    'bloodline',
#    'hatched',
#    'july',
#    'asking',
#    'male',
#    'female',
#    'left',
#    'please',
#    'email',
#    'vcbevilacqua',
#    'aol',
#    'com',
#    'text',
#    'picture',
#    'snake',
#    'ny',
#    'thankyou']},
#  {'User_name': 'fitz505',
#   'AD_name': '2018 holdback Woma Python',
#   'Date': '09-27-2019, 12:07 PM',
#   'Type_1': '> Reptile & Amphibian - Classifieds',
#   'Type_2': '> Snakes For Sale/Wanteds',
#   'Type_3': '> Arboreal Boas/Pythons',
#   'Sale_or_no': '2018 holdback Woma Python',
#   'Price': '300',
#   'Keywords': ['male',
#    'woma',
#    'python',
#    'sale',
#    'anyone',
#    'interested',
#    'obo']},
#  {'User_name': 'cbass',
#   'AD_name': '2018 0.1 Gamma Carpet Python',
#   'Date': '09-10-2019, 11:46 PM',
#   'Type_1': '> Reptile & Amphibian - Classifieds',
#   'Type_2': '> Snakes For Sale/Wanteds',
#   'Type_3': '> Arboreal Boas/Pythons',
#   'Sale_or_no': '[SOLD!!] 2018 0.1 Gamma Carpet Python',
#   'Price': '400',
#   'Keywords': ['beautiful',
#    'juvenile',
#    'female',
#    'gaining',
#    'yellow',
#    'shed',
#    'healthy',
#    'friendly',
#    'eating',
#    'ft',
#    'mouse',
#    'fuzzies',
#    'hopper',
#    'weekly',
#    'asking',
#    'obo',
#    'plus',
#    'actual',
#    'cost',
#    'fedex',
#    'overnight',
#    'shipping',
#    'depending',
#    'location']},
#  {'User_name': 'bill albright',
#   'AD_name': '0.1 bredli carpet ! beautiful !',
#   'Date': '09-07-2019, 11:53 AM',
#   'Type_1': '> Reptile & Amphibian - Classifieds',
#   'Type_2': '> Snakes For Sale/Wanteds',
#   'Type_3': '> Arboreal Boas/Pythons',
#   'Sale_or_no': '0.1 bredli carpet ! beautiful !',
#   'Price': '450',
#   'Keywords': ['absolutely',
#    'gorgeous',
#    'female',
#    'bredli',
#    'feeding',
#    'small',
#    'rat',
#    'plus',
#    'shipping']},
#  {'User_name': 'FBskateboarder',
#   'AD_name': '2019 Female Jungle Carpet',
#   'Date': '09-05-2019, 12:21 PM',
#   'Type_1': '> Reptile & Amphibian - Classifieds',
#   'Type_2': '> Snakes For Sale/Wanteds',
#   'Type_3': '> Arboreal Boas/Pythons',
#   'Sale_or_no': '[For Sale] 2019 Female Jungle Carpet',
#   'Price': '450',
#   'Keywords': ['offering',
#    'german',
#    'harris',
#    'line',
#    'female',
#    'sale',
#    'produced',
#    'david',
#    'haisten',
#    'chondro',
#    'jungle',
#    'meal',
#    'far',
#    'shipped']},
#  {'User_name': 'Snakeinc',
#   'AD_name': '2015 female Red tiger jag',
#   'Date': '08-20-2019, 01:40 PM',
#   'Type_1': '> Reptile & Amphibian - Classifieds',
#   'Type_2': '> Snakes For Sale/Wanteds',
#   'Type_3': '> Arboreal Boas/Pythons',
#   'Sale_or_no': '[For Sale] 2015 female Red tiger jag',
#   'Price': '500',
#   'Keywords': ['paired',
#    'female',
#    'late',
#    'season',
#    'got',
#    'slug',
#    'july',
#    'th',
#    'meal',
#    'back',
#    'sign',
#    'slowing',
#    'started',
#    'small',
#    'rat',
#    'last',
#    'medium',
#    'normal',
#    'diet',
#    'asking',
#    'local',
#    'pick',
#    'located',
#    'pittsburgh',
#    'pa',
#    'ship',
#    'additional']},
#  {'User_name': 'MartinR',
#   'AD_name': '2019 Lemke x Hamper male Jungles',
#   'Date': '08-30-2019, 03:21 PM',
#   'Type_1': '> Reptile & Amphibian - Classifieds',
#   'Type_2': '> Snakes For Sale/Wanteds',
#   'Type_3': '> Arboreal Boas/Pythons',
#   'Sale_or_no': '[For Sale] 2019 Lemke x Hamper male Jungles',
#   'Price': '400',
#   'Keywords': ['male',
#    'crazy',
#    'pattern',
#    'stripe',
#    'dam',
#    'awesome',
#    'lemke',
#    'hamper',
#    'pairing',
#    'plus',
#    'shipping',
#    'pic',
#    'parent',
#    'available',
#    'mail',
#    'faster',
#    'response',
#    'nd',
#    'sold']},
#  {'User_name': 'KelcifersDragons',
#   'AD_name': 'Bredli python pair',
#   'Date': '08-07-2019, 04:50 AM',
#   'Type_1': '> Reptile & Amphibian - Classifieds',
#   'Type_2': '> Snakes For Sale/Wanteds',
#   'Type_3': '> Arboreal Boas/Pythons',
#   'Sale_or_no': 'Bredli python pair',
#   'Price': '575',
#   'Keywords': ['pair',
#    'bredli',
#    'python',
#    'male',
#    'producing',
#    'sperm',
#    'ready',
#    'breed',
#    'female',
#    'still',
#    'need',
#    'size',
#    'easy',
#    'handle',
#    'great',
#    'feeding',
#    'response',
#    'plus',
#    'shipping',
#    'separate',
#    'much',
#    'info',
#    'ask',
#    'bought',
#    'couple',
#    'year',
#    'ago',
#    'juvie',
#    'raising',
#    'pet',
#    'decided',
#    'let',
#    'go',
#    'pictured',
#    'shed',
#    'picture',
#    'came',
#    'super',
#    'dark']},
#  {'User_name': 'G8trguy76',
#   'AD_name': 'USCBB 2019 Green Tree Python',
#   'Date': '08-22-2019, 03:58 PM',
#   'Type_1': '> Reptile & Amphibian - Classifieds',
#   'Type_2': '> Snakes For Sale/Wanteds',
#   'Type_3': '> Arboreal Boas/Pythons',
#   'Sale_or_no': '[For Sale] USCBB 2019 Green Tree Python',
#   'Price': '900',
#   'Keywords': ['uscbb',
#    'biak',
#    'type',
#    'gtp',
#    'produced',
#    'justin',
#    'smith',
#    'palmetto',
#    'coast',
#    'ecotics',
#    'unsexed',
#    'unassisted',
#    'meal',
#    'ft',
#    'pink',
#    'plus',
#    'shipping',
#    'via',
#    'syr',
#    'email',
#    'information',
#    'isbessell',
#    'gmail',
#    'com']},
#  {'User_name': 'JT690',
#   'AD_name': "Female Stonewashed Bredl's Python",
#   'Date': '08-21-2019, 06:00 PM',
#   'Type_1': '> Reptile & Amphibian - Classifieds',
#   'Type_2': '> Snakes For Sale/Wanteds',
#   'Type_3': '> Arboreal Boas/Pythons',
#   'Sale_or_no': "[For Sale] Female Stonewashed Bredl's Python",
#   'Price': '900',
#   'Keywords': ['girl',
#    'purchased',
#    'nick',
#    'mutton',
#    'wonderful',
#    'feeding',
#    'adult',
#    'mouse',
#    'rat',
#    'pup',
#    'currently',
#    'shed',
#    'last',
#    'picture',
#    'flash',
#    'asking',
#    'plus',
#    'shipping']},
#  {'User_name': 'thafathaa',
#   'AD_name': '*SOLD!!* Amazing 2017 Female Pure Darwin Albino Carpet Python',
#   'Date': '08-18-2019, 11:54 PM',
#   'Type_1': '> Reptile & Amphibian - Classifieds',
#   'Type_2': '> Snakes For Sale/Wanteds',
#   'Type_3': '> Arboreal Boas/Pythons',
#   'Sale_or_no': '*SOLD!!* Amazing 2017 Female Pure Darwin Albino Carpet Python',
#   'Price': '500',
#   'Keywords': ['girl',
#    'definite',
#    'stunner',
#    'sire',
#    'dam',
#    'pure',
#    'darwin',
#    'albino',
#    'produced',
#    'nick',
#    'mutton',
#    'color',
#    'get',
#    'intense',
#    'shed',
#    'take',
#    'home',
#    'plus',
#    'actual',
#    'shipping',
#    'paypal',
#    'accepted',
#    'thanks',
#    'txt']},
#  {'User_name': 'MartinR',
#   'AD_name': '2019 Male Jungle-Zebras',
#   'Date': '08-18-2019, 06:22 PM',
#   'Type_1': '> Reptile & Amphibian - Classifieds',
#   'Type_2': '> Snakes For Sale/Wanteds',
#   'Type_3': '> Arboreal Boas/Pythons',
#   'Sale_or_no': '[For Sale] 2019 Male Jungle-Zebras',
#   'Price': '400',
#   'Keywords': ['nice',
#    'selection',
#    'male',
#    'jungle',
#    'several',
#    'clutch',
#    'hatched',
#    'year',
#    'shed',
#    'least',
#    'time',
#    'eating',
#    'rat',
#    'pink',
#    'tongs',
#    'pairing',
#    'beach',
#    'hamper',
#    'lemke',
#    'line',
#    'hare',
#    'german',
#    'zebra',
#    'attached',
#    'pic',
#    'something',
#    'catch',
#    'eye',
#    'let',
#    'know',
#    'send',
#    'information',
#    'normal',
#    'plus',
#    'shipping']},
#  {'User_name': 'Brian Fischer',
#   'AD_name': 'Yearling Female Papuan Carpet Python',
#   'Date': '08-12-2019, 06:59 PM',
#   'Type_1': '> Reptile & Amphibian - Classifieds',
#   'Type_2': '> Snakes For Sale/Wanteds',
#   'Type_3': '> Arboreal Boas/Pythons',
#   'Sale_or_no': '[For Sale] Yearling Female Papuan Carpet Python',
#   'Price': '250',
#   'Keywords': ['fh',
#    'yearling',
#    'female',
#    'papuan',
#    'carpet',
#    'python',
#    'available',
#    'asking',
#    'shipped',
#    'inquire',
#    'via',
#    'email',
#    'bfischer',
#    'hotmail',
#    'com']},
#  {'User_name': 'MatthewH',
#   'AD_name': "USCB '15 GTP",
#   'Date': '08-11-2019, 06:11 PM',
#   'Type_1': '> Reptile & Amphibian - Classifieds',
#   'Type_2': '> Snakes For Sale/Wanteds',
#   'Type_3': '> Arboreal Boas/Pythons',
#   'Sale_or_no': "[For Sale] USCB '15 GTP",
#   'Price': '1100',
#   'Keywords': ['male',
#    'gtp',
#    'produced',
#    'tk',
#    'chondros',
#    'noah',
#    'norah',
#    'pairing',
#    'asking',
#    'shipped',
#    'amazing',
#    'looking',
#    'send',
#    'picture',
#    'parent',
#    'like']},
#  {'User_name': 'vicbevpines',
#   'AD_name': '2019 Jungle Carpet Pythons Lazik/vpi',
#   'Date': '08-03-2019, 03:15 PM',
#   'Type_1': '> Reptile & Amphibian - Classifieds',
#   'Type_2': '> Snakes For Sale/Wanteds',
#   'Type_3': '> Arboreal Boas/Pythons',
#   'Sale_or_no': '2019 Jungle Carpet Pythons Lazik/vpi',
#   'Price': '250',
#   'Keywords': ['jungle',
#    'carpet',
#    'python',
#    'lazik',
#    'vpi',
#    'bloodline',
#    'eating',
#    'frozen',
#    'thawed',
#    'pinky',
#    'asking',
#    'pair',
#    'male',
#    'female',
#    'available',
#    'please',
#    'email',
#    'vcbevilacqua',
#    'aol',
#    'com',
#    'pic',
#    'parent',
#    'baby',
#    'located',
#    'staten',
#    'island',
#    'ny']},
#  {'User_name': 'hpc1979',
#   'AD_name': 'Sorong Green Tree Python',
#   'Date': '07-13-2019, 07:50 PM',
#   'Type_1': '> Reptile & Amphibian - Classifieds',
#   'Type_2': '> Snakes For Sale/Wanteds',
#   'Type_3': '> Arboreal Boas/Pythons',
#   'Sale_or_no': 'Sorong Green Tree Python',
#   'Price': '600',
#   'Keywords': ['selling',
#    'year',
#    'old',
#    'unsexed',
#    'sorong',
#    'green',
#    'tree',
#    'python',
#    'looking',
#    'local',
#    'sale',
#    'philadelphia',
#    'area',
#    'asking',
#    'obo',
#    'question',
#    'please',
#    'text']},
#  {'User_name': 'FBskateboarder',
#   'AD_name': '2019 Male JCP',
#   'Date': '07-08-2019, 11:45 PM',
#   'Type_1': '> Reptile & Amphibian - Classifieds',
#   'Type_2': '> Snakes For Sale/Wanteds',
#   'Type_3': '> Arboreal Boas/Pythons',
#   'Sale_or_no': '[For Sale] 2019 Male JCP',
#   'Price': '450',
#   'Keywords': ['german',
#    'harris',
#    'line',
#    'male',
#    'collaborative',
#    'pairing',
#    'produced',
#    'david',
#    'haisten',
#    'chondro',
#    'jungle',
#    'decided',
#    'want',
#    'move',
#    'hatchling',
#    'rack',
#    'shipped']},
#  {'User_name': 'SalvadoriiSam',
#   'AD_name': 'Male Jaguar Carpet Python',
#   'Date': '06-24-2019, 01:42 PM',
#   'Type_1': '> Reptile & Amphibian - Classifieds',
#   'Type_2': '> Snakes For Sale/Wanteds',
#   'Type_3': '> Arboreal Boas/Pythons',
#   'Sale_or_no': '[For Sale] Male Jaguar Carpet Python',
#   'Price': '300',
#   'Keywords': ['hello',
#    'currently',
#    'beautiful',
#    'adult',
#    'male',
#    'jaguar',
#    'carpet',
#    'python',
#    'available',
#    'never',
#    'miss',
#    'meal',
#    'temperment',
#    'great',
#    'cage',
#    'asking',
#    'shipping',
#    'question',
#    'feel',
#    'free',
#    'message',
#    'email']},
#  {'User_name': 'JaredRang',
#   'AD_name': 'Dominican Red Mountain Boas',
#   'Date': '06-22-2019, 06:03 PM',
#   'Type_1': '> Reptile & Amphibian - Classifieds',
#   'Type_2': '> Snakes For Sale/Wanteds',
#   'Type_3': '> Arboreal Boas/Pythons',
#   'Sale_or_no': 'Dominican Red Mountain Boas',
#   'Price': '600',
#   'Keywords': ['baby',
#    'dominican',
#    'red',
#    'mountain',
#    'boa',
#    'sale',
#    'eating',
#    'unscented',
#    'rat',
#    'pink',
#    'beautiful',
#    'whose',
#    'parent',
#    'came',
#    'crutchfield',
#    'line',
#    'pr',
#    'shipping']},
#  {'User_name': 'Jefedeuce',
#   'AD_name': '2018 0.1 cbb northern etb',
#   'Date': '06-19-2019, 11:38 PM',
#   'Type_1': '> Reptile & Amphibian - Classifieds',
#   'Type_2': '> Snakes For Sale/Wanteds',
#   'Type_3': '> Arboreal Boas/Pythons',
#   'Sale_or_no': '[For Sale] 2018 0.1 cbb northern etb',
#   'Price': '600',
#   'Keywords': ['sold',
#    'since',
#    'red',
#    'neonate',
#    'pic',
#    'thru',
#    'ontogenetic',
#    'color',
#    'change',
#    'green',
#    'eats',
#    'hopper',
#    'although',
#    'eat',
#    'rat',
#    'pink',
#    'fuzzys',
#    'fed',
#    'slower',
#    'powerfeed',
#    'potentially',
#    'cause',
#    'regurgitation',
#    'syndrome',
#    'completely',
#    'tame',
#    'hold',
#    'wish',
#    'dont',
#    'often',
#    'sometime',
#    'pull',
#    'calm',
#    'snake',
#    'light',
#    'go',
#    'aggressively',
#    'gusto',
#    'shipping',
#    'selling',
#    'focus',
#    'sd',
#    'retic',
#    'project',
#    'interested',
#    'contact',
#    'nick',
#    'jones']},
#  {'User_name': 'MartinR',
#   'AD_name': '2019 Male Hare-German Line Jungles',
#   'Date': '06-20-2019, 12:26 PM',
#   'Type_1': '> Reptile & Amphibian - Classifieds',
#   'Type_2': '> Snakes For Sale/Wanteds',
#   'Type_3': '> Arboreal Boas/Pythons',
#   'Sale_or_no': '[For Sale] 2019 Male Hare-German Line Jungles',
#   'Price': '400',
#   'Keywords': ['male',
#    'normal',
#    'jungle',
#    'available',
#    'hare',
#    'gb',
#    'zebra',
#    'boy',
#    'going',
#    'awesome',
#    'eating',
#    'rat',
#    'pink',
#    'asking',
#    'plus',
#    'shipping',
#    'serious',
#    'inquiry',
#    'please',
#    'mail',
#    'faster',
#    'response',
#    'thanks',
#    'looking']},
#  {'User_name': 'MartinR',
#   'AD_name': '2019 Male Hare-German Line Jungle Zebras',
#   'Date': '06-20-2019, 12:21 PM',
#   'Type_1': '> Reptile & Amphibian - Classifieds',
#   'Type_2': '> Snakes For Sale/Wanteds',
#   'Type_3': '> Arboreal Boas/Pythons',
#   'Sale_or_no': '[For Sale] 2019 Male Hare-German Line Jungle Zebras',
#   'Price': '500',
#   'Keywords': ['male',
#    'zebra',
#    'available',
#    'hare',
#    'gb',
#    'boy',
#    'going',
#    'awesome',
#    'eating',
#    'rat',
#    'pink',
#    'asking',
#    'plus',
#    'shipping',
#    'serious',
#    'inquiry',
#    'please',
#    'mail',
#    'faster',
#    'response',
#    'thanks',
#    'looking']},
#  {'User_name': 'MartinR',
#   'AD_name': '2019 Female Hare-German Line Jungle Zebras',
#   'Date': '06-20-2019, 12:17 PM',
#   'Type_1': '> Reptile & Amphibian - Classifieds',
#   'Type_2': '> Snakes For Sale/Wanteds',
#   'Type_3': '> Arboreal Boas/Pythons',
#   'Sale_or_no': '[For Sale] 2019 Female Hare-German Line Jungle Zebras',
#   'Price': '500',
#   'Keywords': ['female',
#    'zebra',
#    'available',
#    'hare',
#    'gb',
#    'girl',
#    'going',
#    'awesome',
#    'eating',
#    'rat',
#    'pink',
#    'asking',
#    'plus',
#    'shipping',
#    'serious',
#    'inquiry',
#    'please',
#    'mail',
#    'faster',
#    'response',
#    'thanks',
#    'looking']},
#  {'User_name': 'MartinR',
#   'AD_name': '1.1 2019 MBeach-VPI x Hamper jungles',
#   'Date': '06-20-2019, 12:05 PM',
#   'Type_1': '> Reptile & Amphibian - Classifieds',
#   'Type_2': '> Snakes For Sale/Wanteds',
#   'Type_3': '> Arboreal Boas/Pythons',
#   'Sale_or_no': '[SOLD!!] 1.1 2019 MBeach-VPI x Hamper jungles',
#   'Price': '400',
#   'Keywords': ['jungle',
#    'baby',
#    'mbeach',
#    'vpi',
#    'hamper',
#    'clutch',
#    'ready',
#    'go',
#    'eating',
#    'pink',
#    'fuzzies',
#    'pic',
#    'dam',
#    'sire',
#    'female',
#    'male',
#    'order',
#    'asking',
#    'plus',
#    'shipping',
#    'serious',
#    'inquiry',
#    'please',
#    'thanks',
#    'looking',
#    'mail',
#    'faster',
#    'response',
#    'sold']},
#  {'User_name': 'Finneran74',
#   'AD_name': 'Gtp male',
#   'Date': '06-19-2019, 09:47 PM',
#   'Type_1': '> Reptile & Amphibian - Classifieds',
#   'Type_2': '> Snakes For Sale/Wanteds',
#   'Type_3': '> Arboreal Boas/Pythons',
#   'Sale_or_no': 'Gtp male',
#   'Price': '600',
#   'Keywords': ['sold',
#    'year',
#    'old',
#    'male',
#    'biak',
#    'maurake',
#    'gtp',
#    'docile',
#    'handled',
#    'lot',
#    'many',
#    'project',
#    'going',
#    'would',
#    'keeping',
#    'asking',
#    'plus',
#    'shipping']},
#  {'User_name': 'PalmetttoCoastExotics',
#   'AD_name': '1.0 bredli 2017',
#   'Date': '06-18-2019, 01:48 PM',
#   'Type_1': '> Reptile & Amphibian - Classifieds',
#   'Type_2': '> Snakes For Sale/Wanteds',
#   'Type_3': '> Arboreal Boas/Pythons',
#   'Sale_or_no': '[SOLD!!] 1.0 bredli 2017',
#   'Price': '150',
#   'Keywords': ['bredl',
#    'grab',
#    'eats',
#    'like',
#    'champ',
#    'small',
#    'hopper',
#    'coloring',
#    'nicely',
#    'plus',
#    'shipping',
#    'email',
#    'palmettocoastexotics',
#    'gmail',
#    'com',
#    'question']},
#  {'User_name': 'Alex.willi0513',
#   'AD_name': 'DBL HET LAV Purple Albino Reticulated python',
#   'Date': '05-23-2019, 02:50 PM',
#   'Type_1': '> Reptile & Amphibian - Classifieds',
#   'Type_2': '> Snakes For Sale/Wanteds',
#   'Type_3': '> Arboreal Boas/Pythons',
#   'Sale_or_no': '[For Sale] DBL HET LAV Purple Albino Reticulated python',
#   'Price': '400',
#   'Keywords': ['hello',
#    'female',
#    'dbl',
#    'het',
#    'lav',
#    'purple',
#    'albino',
#    'reticulated',
#    'python',
#    'sale',
#    'kalamazoo',
#    'mi',
#    'area',
#    'asking',
#    'abaibal',
#    'local',
#    'pickup',
#    'ship']},
#  {'User_name': 'gecko32',
#   'AD_name': 'Mpenn coastal group',
#   'Date': '05-24-2019, 07:22 PM',
#   'Type_1': '> Reptile & Amphibian - Classifieds',
#   'Type_2': '> Snakes For Sale/Wanteds',
#   'Type_3': '> Arboreal Boas/Pythons',
#   'Sale_or_no': 'Mpenn coastal group',
#   'Price': '500',
#   'Keywords': ['mpenn',
#    'coastals',
#    'animal',
#    'red',
#    'line',
#    'coastal',
#    'got',
#    'micheal',
#    'pennell',
#    'asking',
#    'shipped',
#    'eating',
#    'frozen',
#    'thawed',
#    'contact',
#    'cell',
#    'phone',
#    'pic',
#    'serious',
#    'people']},
#  {'User_name': 'ssmith178',
#   'AD_name': '2017 Poss Super Caramel male',
#   'Date': '04-04-2019, 10:29 PM',
#   'Type_1': '> Reptile & Amphibian - Classifieds',
#   'Type_2': '> Snakes For Sale/Wanteds',
#   'Type_3': '> Arboreal Boas/Pythons',
#   'Sale_or_no': '[For Sale] 2017 Poss Super Caramel male',
#   'Price': '200',
#   'Keywords': ['male',
#    'po',
#    'super',
#    'caramel',
#    'produced',
#    'magic',
#    'carpet',
#    'python',
#    'asking',
#    'pay',
#    'ride']},
#  {'User_name': 'ssmith178',
#   'AD_name': '2017 Striped Jungle Pair',
#   'Date': '04-04-2019, 10:34 PM',
#   'Type_1': '> Reptile & Amphibian - Classifieds',
#   'Type_2': '> Snakes For Sale/Wanteds',
#   'Type_3': '> Arboreal Boas/Pythons',
#   'Sale_or_no': '[For Sale] 2017 Striped Jungle Pair',
#   'Price': '550',
#   'Keywords': ['pair',
#    'striped',
#    'jungle',
#    'animal',
#    'female',
#    'first',
#    'pic',
#    'produced',
#    'ed',
#    'lilley',
#    'ivory',
#    'vv',
#    'male',
#    'second',
#    'steven',
#    'katz',
#    'type',
#    'full',
#    'stripe',
#    'nice',
#    'yellow',
#    'glow',
#    'asking',
#    'pay',
#    'ride']},
#  {'User_name': 'ScruffyBuffalo',
#   'AD_name': '2017 Male Hypo Bredli',
#   'Date': '05-07-2019, 06:06 PM',
#   'Type_1': '> Reptile & Amphibian - Classifieds',
#   'Type_2': '> Snakes For Sale/Wanteds',
#   'Type_3': '> Arboreal Boas/Pythons',
#   'Sale_or_no': '[For Sale] 2017 Male Hypo Bredli',
#   'Price': '1100',
#   'Keywords': ['solo',
#    'male',
#    'hypo',
#    'bredli',
#    'sale',
#    'originally',
#    'produced',
#    'nick',
#    'mutton',
#    'purchased',
#    'eating',
#    'pup',
#    'weaned',
#    'rat',
#    'week',
#    'asking',
#    'shipped',
#    'accepting',
#    'trade',
#    'moment']},
#  {'User_name': 'MartinR',
#   'AD_name': 'Amazing 2.2 Stonewashed Bredli',
#   'Date': '05-05-2019, 05:50 PM',
#   'Type_1': '> Reptile & Amphibian - Classifieds',
#   'Type_2': '> Snakes For Sale/Wanteds',
#   'Type_3': '> Arboreal Boas/Pythons',
#   'Sale_or_no': '[For Sale] Amazing 2.2 Stonewashed Bredli',
#   'Price': '1,100.00',
#   'Keywords': ['available',
#    'guy',
#    'amazing',
#    'extremely',
#    'light',
#    'color',
#    'enhancing',
#    'stonewashed',
#    'look',
#    'eating',
#    'rat',
#    'pup',
#    'without',
#    'hesitation',
#    'asking',
#    'plus',
#    'shipping',
#    'better',
#    'price',
#    'pair',
#    'trio',
#    'mail',
#    'faster',
#    'response',
#    'thanks']},
#  {'User_name': 'MatthewH',
#   'AD_name': 'Aru/Biak 2013 USCB',
#   'Date': '05-03-2019, 06:55 PM',
#   'Type_1': '> Reptile & Amphibian - Classifieds',
#   'Type_2': '> Snakes For Sale/Wanteds',
#   'Type_3': '> Arboreal Boas/Pythons',
#   'Sale_or_no': 'Aru/Biak 2013 USCB',
#   'Price': '775',
#   'Keywords': ['male',
#    'aru',
#    'biak',
#    'green',
#    'tree',
#    'python',
#    'sale',
#    'sold',
#    'captive',
#    'born',
#    'animal',
#    'amazing',
#    'blue',
#    'yellow',
#    'white',
#    'asking',
#    'shipped',
#    'great',
#    'looking']},
#  {'User_name': 'tracy reptile co.',
#   'AD_name': 'Baby sorong male and high white aru female',
#   'Date': '04-26-2019, 06:55 PM',
#   'Type_1': '> Reptile & Amphibian - Classifieds',
#   'Type_2': '> Snakes For Sale/Wanteds',
#   'Type_3': '> Arboreal Boas/Pythons',
#   'Sale_or_no': '[For Sale] Baby sorong male and high white aru female',
#   'Price': '600',
#   'Keywords': ['baby',
#    'male',
#    'sorong',
#    'currently',
#    'color',
#    'changing',
#    'asking',
#    'plus',
#    'shipping']},
#  {'User_name': 'Rockabirdie',
#   'AD_name': 'Stunning Sorong Female!!',
#   'Date': '08-16-2018, 01:45 AM',
#   'Type_1': '> Reptile & Amphibian - Classifieds',
#   'Type_2': '> Snakes For Sale/Wanteds',
#   'Type_3': '> Arboreal Boas/Pythons',
#   'Sale_or_no': '[For Sale] Stunning Sorong Female!!',
#   'Price': '650',
#   'Keywords': ['girl',
#    'beauty',
#    'taking',
#    'live',
#    'small',
#    'rat',
#    'never',
#    'refuse',
#    'regurgitated',
#    'captivity',
#    'year',
#    'treated',
#    'solid',
#    'healthy',
#    'animal',
#    'plus',
#    'shipping']},
#  {'User_name': 'Zgrant1000',
#   'AD_name': 'Emerald tree boa',
#   'Date': '04-17-2019, 02:17 AM',
#   'Type_1': '> Reptile & Amphibian - Classifieds',
#   'Type_2': '> Snakes For Sale/Wanteds',
#   'Type_3': '> Arboreal Boas/Pythons',
#   'Sale_or_no': 'Emerald tree boa',
#   'Price': '400',
#   'Keywords': ['adult',
#    'female',
#    'emerald',
#    'tree',
#    'boa',
#    'plus',
#    'shipping',
#    'currently',
#    'feeding',
#    'small',
#    'rat',
#    'import',
#    'guyana',
#    'treated',
#    'external',
#    'parasite']},
#  {'User_name': 'Python Addiction',
#   'AD_name': 'Female Biak gtp',
#   'Date': '04-06-2019, 06:24 PM',
#   'Type_1': '> Reptile & Amphibian - Classifieds',
#   'Type_2': '> Snakes For Sale/Wanteds',
#   'Type_3': '> Arboreal Boas/Pythons',
#   'Sale_or_no': 'Female Biak gtp',
#   'Price': '375',
#   'Keywords': ['cb',
#    'female',
#    'pure',
#    'biak',
#    'gtp',
#    'slightly',
#    'aggressive',
#    'feeding',
#    'great',
#    'mouse',
#    'beautiful',
#    'snake',
#    'yellow',
#    'neonate',
#    'believe',
#    'selling',
#    'shipping',
#    'price',
#    'firm',
#    'trade',
#    'getting',
#    'call',
#    'text',
#    'fastest',
#    'response',
#    'rarely',
#    'healthy',
#    'mite',
#    'free']},
#  {'User_name': 'MartinR',
#   'AD_name': 'High% Highlighter Male Jungle',
#   'Date': '04-07-2019, 06:43 PM',
#   'Type_1': '> Reptile & Amphibian - Classifieds',
#   'Type_2': '> Snakes For Sale/Wanteds',
#   'Type_3': '> Arboreal Boas/Pythons',
#   'Sale_or_no': '[SOLD!!] High% Highlighter Male Jungle',
#   'Price': '550',
#   'Keywords': ['outstanding',
#    'year',
#    'old',
#    'highlighter',
#    'male',
#    'grab',
#    'oddly',
#    'banded',
#    'line',
#    'killer',
#    'non',
#    'le',
#    'known',
#    'charlie',
#    'brown',
#    'dude',
#    'slamming',
#    'small',
#    'rat',
#    'gusto',
#    'asking',
#    'plus',
#    'shipping',
#    'mail',
#    'faster',
#    'response',
#    'thanks',
#    'looking']},
#  {'User_name': 'MartinR',
#   'AD_name': '2015 Caramel Zebra Granite Female',
#   'Date': '03-27-2019, 07:24 AM',
#   'Type_1': '> Reptile & Amphibian - Classifieds',
#   'Type_2': '> Snakes For Sale/Wanteds',
#   'Type_3': '> Arboreal Boas/Pythons',
#   'Sale_or_no': '[SOLD!!] 2015 Caramel Zebra Granite Female',
#   'Price': '1250',
#   'Keywords': ['purchased',
#    'gorgeous',
#    'girl',
#    'intent',
#    'breeding',
#    'female',
#    'zebra',
#    'granite',
#    'obviously',
#    'work',
#    'well',
#    'grab',
#    'aggressively',
#    'feeding',
#    'medium',
#    'rat',
#    'asking',
#    'shipped',
#    'obro']},
#  {'User_name': 'MartinR',
#   'AD_name': 'Stonewashed Bredli Pair',
#   'Date': '03-27-2019, 07:13 AM',
#   'Type_1': '> Reptile & Amphibian - Classifieds',
#   'Type_2': '> Snakes For Sale/Wanteds',
#   'Type_3': '> Arboreal Boas/Pythons',
#   'Sale_or_no': '[For Sale] Stonewashed Bredli Pair',
#   'Price': '1550',
#   'Keywords': ['nice',
#    'big',
#    'stonewashed',
#    'bredli',
#    'pair',
#    'grab',
#    'het',
#    'female',
#    'visual',
#    'male',
#    'slamming',
#    'rat',
#    'pup',
#    'without',
#    'hesitation',
#    'pic',
#    'guy',
#    'justice',
#    'asking',
#    'shipped',
#    'please',
#    'mail',
#    'faster',
#    'response',
#    'question',
#    'serious',
#    'inquires',
#    'several',
#    'solo',
#    'animal',
#    'well']},
#  {'User_name': 'gecko32',
#   'AD_name': '2018 1.2 Nova Guineas',
#   'Date': '03-27-2019, 05:46 AM',
#   'Type_1': '> Reptile & Amphibian - Classifieds',
#   'Type_2': '> Snakes For Sale/Wanteds',
#   'Type_3': '> Arboreal Boas/Pythons',
#   'Sale_or_no': '2018 1.2 Nova Guineas',
#   'Price': '650',
#   'Keywords': ['opportunity',
#    'presented',
#    'offering',
#    'produced',
#    'eric',
#    'koller',
#    'feeding',
#    'fuzzy',
#    'mouse',
#    'asking',
#    'shipped',
#    'firm',
#    'contact',
#    'cell',
#    'text',
#    'pic']},
#  {'User_name': 'MartinR',
#   'AD_name': '1.2 Hypo Bredli',
#   'Date': '02-17-2019, 04:22 PM',
#   'Type_1': '> Reptile & Amphibian - Classifieds',
#   'Type_2': '> Snakes For Sale/Wanteds',
#   'Type_3': '> Arboreal Boas/Pythons',
#   'Sale_or_no': '[For Sale] 1.2 Hypo Bredli',
#   'Price': '1150',
#   'Keywords': ['hypo',
#    'bredli',
#    'available',
#    'breeding',
#    'slamming',
#    'rat',
#    'pup',
#    'asking',
#    'mail',
#    'faster',
#    'response',
#    'thank',
#    'looking']},
#  {'User_name': 'MartinR',
#   'AD_name': '1.2 Stonewashed Bredli',
#   'Date': '02-17-2019, 04:11 PM',
#   'Type_1': '> Reptile & Amphibian - Classifieds',
#   'Type_2': '> Snakes For Sale/Wanteds',
#   'Type_3': '> Arboreal Boas/Pythons',
#   'Sale_or_no': '[For Sale] 1.2 Stonewashed Bredli',
#   'Price': '1150',
#   'Keywords': ['beautifully',
#    'colored',
#    'stonewashed',
#    'bredli',
#    'grab',
#    'amazing',
#    'example',
#    'morph',
#    'slamming',
#    'rat',
#    'pink',
#    'small',
#    'pup',
#    'without',
#    'hesitation',
#    'asking',
#    'pair',
#    'mail',
#    'faster',
#    'response',
#    'thanks',
#    'looking']},
#  {'User_name': 'JayM',
#   'AD_name': 'High White Pure Darwin male',
#   'Date': '02-05-2019, 01:59 PM',
#   'Type_1': '> Reptile & Amphibian - Classifieds',
#   'Type_2': '> Snakes For Sale/Wanteds',
#   'Type_3': '> Arboreal Boas/Pythons',
#   'Sale_or_no': 'High White Pure Darwin male',
#   'Price': '600',
#   'Keywords': ['sold',
#    'pure',
#    'darwin',
#    'carpet',
#    'male',
#    'bloodline',
#    'originated',
#    'zoo',
#    'south',
#    'africa',
#    'produced',
#    'best',
#    'boids',
#    'great',
#    'eater',
#    'shed',
#    'perfect',
#    'every',
#    'time',
#    'health',
#    'shipping',
#    'picked',
#    'white',
#    'plain',
#    'weekend',
#    'call',
#    'email',
#    'info',
#    'thanks',
#    'jay',
#    'mclear']},
#  {'User_name': 'MatthewH',
#   'AD_name': '2018 Incredible CB Lereh Green Tree Python Neo $575 Shipped',
#   'Date': '01-06-2019, 08:44 PM',
#   'Type_1': '> Reptile & Amphibian - Classifieds',
#   'Type_2': '> Snakes For Sale/Wanteds',
#   'Type_3': '> Arboreal Boas/Pythons',
#   'Sale_or_no': '[For Sale] 2018 Incredible CB Lereh Green Tree Python Neo $575 Shipped',
#   'Price': '575',
#   'Keywords': ['putting',
#    'beautiful',
#    'green',
#    'tree',
#    'sale',
#    'become',
#    'amazing',
#    'looking',
#    'adult',
#    'lot',
#    'blue',
#    'white',
#    'asking',
#    'shipping',
#    'please',
#    'text',
#    'serious',
#    'inquiry']},
#  {'User_name': 'NoahC.',
#   'AD_name': '2016 female high % IJ Granite',
#   'Date': '08-02-2017, 12:02 AM',
#   'Type_1': '> Reptile & Amphibian - Classifieds',
#   'Type_2': '> Snakes For Sale/Wanteds',
#   'Type_3': '> Arboreal Boas/Pythons',
#   'Sale_or_no': '2016 female high % IJ Granite',
#   'Price': '300',
#   'Keywords': ['produced',
#    'star',
#    'python',
#    'girl',
#    'really',
#    'pretty',
#    'eating',
#    'anything',
#    'shipped']},
#  {'User_name': 'MatthewH',
#   'AD_name': "Green Tree Python CB'18 Jayapura Incredible Red Neo $500 Shipped",
#   'Date': '11-28-2018, 11:20 PM',
#   'Type_1': '> Reptile & Amphibian - Classifieds',
#   'Type_2': '> Snakes For Sale/Wanteds',
#   'Type_3': '> Arboreal Boas/Pythons',
#   'Sale_or_no': "[For Sale] Green Tree Python CB'18 Jayapura Incredible Red Neo $500 Shipped",
#   'Price': '500',
#   'Keywords': ['incredible',
#    'neonate',
#    'green',
#    'tree',
#    'python',
#    'sale',
#    'jayapura',
#    'type',
#    'asking',
#    'shipped',
#    'text',
#    'serious',
#    'buyer']},
#  {'User_name': 'DendroRob',
#   'AD_name': '2 Baby Biak GTPs',
#   'Date': '12-26-2018, 10:39 PM',
#   'Type_1': '> Reptile & Amphibian - Classifieds',
#   'Type_2': '> Snakes For Sale/Wanteds',
#   'Type_3': '> Arboreal Boas/Pythons',
#   'Sale_or_no': '[For Sale] 2 Baby Biak GTPs',
#   'Price': '200',
#   'Keywords': ['biak',
#    'green',
#    'tree',
#    'looking',
#    'rehome',
#    'got',
#    'friend',
#    'afraid',
#    'fit',
#    'future',
#    'plan',
#    'currently',
#    'feeding',
#    'ft',
#    'fuzzies',
#    'asking',
#    'plus',
#    'shipping']},
#  {'User_name': 'Steve.Anderson',
#   'AD_name': 'Female Carpet Python',
#   'Date': '12-20-2018, 03:11 PM',
#   'Type_1': '> Reptile & Amphibian - Classifieds',
#   'Type_2': '> Snakes For Sale/Wanteds',
#   'Type_3': '> Arboreal Boas/Pythons',
#   'Sale_or_no': '[Wanted] Female Carpet Python',
#   'Price': '300',
#   'Keywords': ['hello',
#    'trying',
#    'get',
#    'started',
#    'breeding',
#    'carpet',
#    'python',
#    'male',
#    'ready',
#    'breed',
#    'next',
#    'year',
#    'looking',
#    'beautiful',
#    'female',
#    'size',
#    'fund',
#    'afford',
#    'expensive',
#    'snake',
#    'could',
#    'pay',
#    'baby',
#    'make',
#    'huge',
#    'profit',
#    'definitely',
#    'repay',
#    'seller',
#    'future',
#    'giving',
#    'offspring',
#    'free']},
#  {'User_name': 'TheJungleFlorida',
#   'AD_name': '**SALE** Albino Darwin Carpet Python **SALE**',
#   'Date': '04-17-2018, 03:50 PM',
#   'Type_1': '> Reptile & Amphibian - Classifieds',
#   'Type_2': '> Snakes For Sale/Wanteds',
#   'Type_3': '> Arboreal Boas/Pythons',
#   'Sale_or_no': '[For Sale] **SALE** Albino Darwin Carpet Python **SALE**',
#   'Price': '300',
#   'Keywords': ['sale', 'plus', 'shipping', 'cost']},
#  {'User_name': 'MartinR',
#   'AD_name': '2018 Jungle male (Leary-Hare-HH)',
#   'Date': '10-23-2018, 02:46 PM',
#   'Type_1': '> Reptile & Amphibian - Classifieds',
#   'Type_2': '> Snakes For Sale/Wanteds',
#   'Type_3': '> Arboreal Boas/Pythons',
#   'Sale_or_no': '[For Sale] 2018 Jungle male (Leary-Hare-HH)',
#   'Price': '450',
#   'Keywords': ['male',
#    'jungle',
#    'andrew',
#    'paris',
#    'jada',
#    'slowhand',
#    'clutch',
#    'picked',
#    'many',
#    'baby',
#    'year',
#    'chance',
#    'grab',
#    'guy',
#    'going',
#    'killer',
#    'adult',
#    'eating',
#    'rat',
#    'pink',
#    'tongs',
#    'without',
#    'hesitation',
#    'shipped',
#    'mail',
#    'faster',
#    'response',
#    'thanks',
#    'looking']},
#  {'User_name': '2by2',
#   'AD_name': 'MALE GARDEN TIGER AMAZON TREE BOA',
#   'Date': '08-10-2018, 02:09 AM',
#   'Type_1': '> Reptile & Amphibian - Classifieds',
#   'Type_2': '> Snakes For Sale/Wanteds',
#   'Type_3': '> Arboreal Boas/Pythons',
#   'Sale_or_no': '[SOLD!!] MALE GARDEN TIGER AMAZON TREE BOA',
#   'Price': '500',
#   'Keywords': ['male',
#    'garden',
#    'tiger',
#    'plus',
#    'shipping',
#    'produce',
#    'beauty',
#    'care',
#    'last',
#    'month',
#    'thriving',
#    'eating',
#    'hopper',
#    'rat',
#    'fuzzies',
#    'gusto',
#    'shedding',
#    'perfectly',
#    'super',
#    'clean',
#    'example',
#    'morph',
#    'soft',
#    'background',
#    'color',
#    'well',
#    'defined',
#    'chocolate',
#    'stripe',
#    'unique',
#    'retained',
#    'bit',
#    'orange',
#    'much',
#    'longer',
#    'anticipated',
#    'pic',
#    'sibling',
#    'parent',
#    'grandparent',
#    'available',
#    'apon',
#    'request',
#    'come',
#    'feed',
#    'shed',
#    'record',
#    'day',
#    'health',
#    'guarantee',
#    'additionally',
#    'able',
#    'help',
#    'way',
#    'throughout',
#    'ownership',
#    'snake',
#    'phone',
#    'call',
#    'pm',
#    'away',
#    'eager',
#    'question',
#    'pertaining',
#    'animal',
#    'happy',
#    'answer',
#    'many',
#    'shoot',
#    'feel',
#    'free',
#    'text',
#    'thanks',
#    'looking']},
#  {'User_name': 'racarrino777',
#   'AD_name': 'Neo Jaya F/S NJ',
#   'Date': '10-17-2018, 11:50 PM',
#   'Type_1': '> Reptile & Amphibian - Classifieds',
#   'Type_2': '> Snakes For Sale/Wanteds',
#   'Type_3': '> Arboreal Boas/Pythons',
#   'Sale_or_no': 'Neo Jaya F/S NJ',
#   'Price': '500',
#   'Keywords': ['month',
#    'old',
#    'feeding',
#    'weekly',
#    'frozen',
#    'pinky',
#    'shedding',
#    'regularly',
#    'tact',
#    'steady',
#    'bowel',
#    'movement',
#    'health',
#    'issue',
#    'although',
#    'try',
#    'handle',
#    'much',
#    'young',
#    'age',
#    'temperament',
#    'great',
#    'bite',
#    'cage',
#    'cleaning',
#    'including',
#    'enclosure',
#    'exo',
#    'terra',
#    'along',
#    'lighting',
#    'heat',
#    'lamp',
#    'bulb',
#    'substrate',
#    'decor',
#    'pick',
#    'jersey',
#    'shipping',
#    'asking',
#    'obo',
#    'please',
#    'contact',
#    'interested']},
#  {'User_name': 'MartinR',
#   'AD_name': '1.2 Stonewashed Bredli',
#   'Date': '10-06-2018, 07:59 AM',
#   'Type_1': '> Reptile & Amphibian - Classifieds',
#   'Type_2': '> Snakes For Sale/Wanteds',
#   'Type_3': '> Arboreal Boas/Pythons',
#   'Sale_or_no': '[For Sale] 1.2 Stonewashed Bredli',
#   'Price': '1050',
#   'Keywords': ['yearling',
#    'stonewashed',
#    'bredli',
#    'eating',
#    'rat',
#    'pink',
#    'pup',
#    'tongs',
#    'hesitation',
#    'asking',
#    'shipped',
#    'het',
#    'well',
#    'female',
#    'male',
#    'mail',
#    'faster',
#    'response',
#    'thanks',
#    'looking',
#    'hets',
#    'sold']},
#  {'User_name': 'MartinR',
#   'AD_name': '2.0 Hypo Bredli',
#   'Date': '10-06-2018, 07:46 AM',
#   'Type_1': '> Reptile & Amphibian - Classifieds',
#   'Type_2': '> Snakes For Sale/Wanteds',
#   'Type_3': '> Arboreal Boas/Pythons',
#   'Sale_or_no': '[For Sale] 2.0 Hypo Bredli',
#   'Price': '1050',
#   'Keywords': ['male',
#    'yearling',
#    'hypo',
#    'bredli',
#    'left',
#    'eating',
#    'rat',
#    'pink',
#    'pup',
#    'asking',
#    'shipped',
#    'mail',
#    'faster',
#    'response',
#    'thanks',
#    'looking']},
#  {'User_name': 'SerpentCyclura',
#   'AD_name': 'Male Proven Breeder 3 year old Biak GTP.',
#   'Date': '09-25-2018, 12:40 AM',
#   'Type_1': '> Reptile & Amphibian - Classifieds',
#   'Type_2': '> Snakes For Sale/Wanteds',
#   'Type_3': '> Arboreal Boas/Pythons',
#   'Sale_or_no': '[For Sale] Male Proven Breeder 3 year old Biak GTP.',
#   'Price': '500',
#   'Keywords': ['great',
#    'freindly',
#    'male',
#    'green',
#    'tree',
#    'python',
#    'good',
#    'eater',
#    'zero',
#    'health',
#    'issue',
#    'bred',
#    'female',
#    'gtp',
#    'last',
#    'year',
#    'fertile',
#    'baby',
#    'come',
#    'exoterra',
#    'terraium',
#    'local',
#    'asking']},
#  {'User_name': 'FBskateboarder',
#   'AD_name': 'Wow/Hamilton Female JCP',
#   'Date': '09-22-2018, 06:54 PM',
#   'Type_1': '> Reptile & Amphibian - Classifieds',
#   'Type_2': '> Snakes For Sale/Wanteds',
#   'Type_3': '> Arboreal Boas/Pythons',
#   'Sale_or_no': '[For Sale] Wow/Hamilton Female JCP',
#   'Price': '400',
#   'Keywords': ['offering',
#    'wow',
#    'hamilton',
#    'female',
#    'sale',
#    'came',
#    'small',
#    'currently',
#    'rat',
#    'pup',
#    'growing',
#    'quickly',
#    'going',
#    'shed',
#    'soon',
#    'asking',
#    'shipped']},
#  {'User_name': 'Jeff Schofield',
#   'AD_name': "4.5' Male Jaguar carpet",
#   'Date': '08-07-2018, 02:10 AM',
#   'Type_1': '> Reptile & Amphibian - Classifieds',
#   'Type_2': '> Snakes For Sale/Wanteds',
#   'Type_3': '> Arboreal Boas/Pythons',
#   'Sale_or_no': "4.5' Male Jaguar carpet",
#   'Price': '249',
#   'Keywords': ['say',
#    'jungle',
#    'jaguar',
#    'got',
#    'guy',
#    'deal',
#    'im',
#    'get',
#    'big',
#    'caging',
#    'feeding',
#    'well',
#    'small',
#    'rat',
#    'asking',
#    'plus',
#    'shipping',
#    'trade',
#    'king',
#    'milk',
#    'atbs',
#    'text',
#    'best']},
#  {'User_name': 'MartinR',
#   'AD_name': 'Yearling Ocelot Bredli DJJ',
#   'Date': '09-21-2018, 04:05 PM',
#   'Type_1': '> Reptile & Amphibian - Classifieds',
#   'Type_2': '> Snakes For Sale/Wanteds',
#   'Type_3': '> Arboreal Boas/Pythons',
#   'Sale_or_no': '[SOLD!!] Yearling Ocelot Bredli DJJ',
#   'Price': '900',
#   'Keywords': ['letting',
#    'amazing',
#    'male',
#    'ocelot',
#    'bredli',
#    'djj',
#    'go',
#    'neon',
#    'wow',
#    'jungle',
#    'pairing',
#    'feeding',
#    'aggressively',
#    'rat',
#    'pup',
#    'without',
#    'hesitation',
#    'asking',
#    'shipped',
#    'mail',
#    'faster',
#    'response',
#    'thank',
#    'looking']},
#  {'User_name': 'Tucker4695',
#   'AD_name': '2 Unsexed Atbs!',
#   'Date': '08-19-2018, 09:44 PM',
#   'Type_1': '> Reptile & Amphibian - Classifieds',
#   'Type_2': '> Snakes For Sale/Wanteds',
#   'Type_3': '> Arboreal Boas/Pythons',
#   'Sale_or_no': '2 Unsexed Atbs!',
#   'Price': '140',
#   'Keywords': ['unsure',
#    'age',
#    'sex',
#    'absolutely',
#    'beautiful',
#    'asking',
#    'shipped']},
#  {'User_name': 'JCoal',
#   'AD_name': 'Adult Male Jaguar Carpet Python',
#   'Date': '09-05-2018, 02:32 PM',
#   'Type_1': '> Reptile & Amphibian - Classifieds',
#   'Type_2': '> Snakes For Sale/Wanteds',
#   'Type_3': '> Arboreal Boas/Pythons',
#   'Sale_or_no': '[For Sale] Adult Male Jaguar Carpet Python',
#   'Price': '250',
#   'Keywords': ['thinning',
#    'collection',
#    'college',
#    'unfortunately',
# ...
#    'plus',
#    'shipping']},
#  {'User_name': 'Carolina Reptiles',
#   'AD_name': 'Pastel Clown Ball Pythons',
#   'Date': '02-11-2019, 05:09 PM',
#   'Type_1': '> Reptile & Amphibian - Classifieds',
#   'Type_2': '> Snakes For Sale/Wanteds',
#   'Type_3': '> Ball Pythons',
#   'Sale_or_no': '[For Sale] Pastel Clown Ball Pythons',
#   'Price': '299.99',
#   'Keywords': ['male',
#    'pastel',
#    'clown',
#    'ball',
#    'python',
#    'sale',
#    'shipping',
#    'local',
#    'pick',
#    'available',
#    'please',
#    'visit',
#    'website',
#    'see',
#    'reptile']},
#  {'User_name': 'TurnerReptiles',
#   'AD_name': 'WC adult male ball pythons.',
#   'Date': '01-23-2019, 07:37 PM',
#   'Type_1': '> Reptile & Amphibian - Classifieds',
#   'Type_2': '> Snakes For Sale/Wanteds',
#   'Type_3': '> Ball Pythons',
#   'Sale_or_no': '[For Sale] WC adult male ball pythons.',
#   'Price': '50.00',
#   'Keywords': ['nice',
#    'heavy',
#    'male',
#    'came',
#    'shipment',
#    'offering',
#    'plus',
#    'shipping']},
#  {'User_name': 'catalyst.genetics',
#   'AD_name': '332 gram Male Butter Ball Python',
#   'Date': '01-20-2019, 07:19 AM',
#   'Type_1': '> Reptile & Amphibian - Classifieds',
#   'Type_2': '> Snakes For Sale/Wanteds',
#   'Type_3': '> Ball Pythons',
#   'Sale_or_no': '332 gram Male Butter Ball Python',
#   'Price': '150',
#   'Keywords': ['male',
#    'butter',
#    'ball',
#    'python',
#    'available',
#    'gram',
#    'asking',
#    'located',
#    'san',
#    'jose',
#    'ca',
#    'shipping',
#    'extra',
#    'trade',
#    'welcome']},
#  {'User_name': 'tracy reptile co.',
#   'AD_name': 'SANDBLAST STERLING FEMALE SIBLING TO URBAN CAMO',
#   'Date': '01-16-2019, 04:48 PM',
#   'Type_1': '> Reptile & Amphibian - Classifieds',
#   'Type_2': '> Snakes For Sale/Wanteds',
#   'Type_3': '> Ball Pythons',
#   'Sale_or_no': '[For Sale] SANDBLAST STERLING FEMALE SIBLING TO URBAN CAMO',
#   'Price': '1100',
#   'Keywords': ['born',
#    'sire',
#    'sandblast',
#    'pewter',
#    'fire',
#    'het',
#    'pied',
#    'purchased',
#    'ozzy',
#    'boids',
#    'dam',
#    'po',
#    'im',
#    'sure',
#    'asking',
#    'plus',
#    'shipping']},
#  {'User_name': 'ramrn',
#   'AD_name': '2018 Male Pastel Spied possible enchi het Hypo',
#   'Date': '12-24-2018, 03:27 AM',
#   'Type_1': '> Reptile & Amphibian - Classifieds',
#   'Type_2': '> Snakes For Sale/Wanteds',
#   'Type_3': '> Ball Pythons',
#   'Sale_or_no': '[For Sale] 2018 Male Pastel Spied possible enchi het Hypo',
#   'Price': '450',
#   'Keywords': ['pastel',
#    'spied',
#    'possible',
#    'enchi',
#    'het',
#    'hypo',
#    'available',
#    'feeding',
#    'rat',
#    'pup',
#    'ready',
#    'go',
#    'question',
#    'feel',
#    'free',
#    'contact',
#    'thanks',
#    'rob']},
#  {'User_name': 'JoeRas',
#   'AD_name': 'Banana Champagne Female',
#   'Date': '01-12-2019, 11:12 PM',
#   'Type_1': '> Reptile & Amphibian - Classifieds',
#   'Type_2': '> Snakes For Sale/Wanteds',
#   'Type_3': '> Ball Pythons',
#   'Sale_or_no': '[For Sale] Banana Champagne Female',
#   'Price': '575',
#   'Keywords': ['produced',
#    'girl',
#    'october',
#    'eating',
#    'great',
#    'fuzzy',
#    'rat',
#    'week',
#    'gr',
#    'available',
#    'plus',
#    'actual',
#    'shipping']},
#  {'User_name': 'tracy reptile co.',
#   'AD_name': 'superpastel lesser champagne female subadult',
#   'Date': '01-03-2019, 03:06 PM',
#   'Type_1': '> Reptile & Amphibian - Classifieds',
#   'Type_2': '> Snakes For Sale/Wanteds',
#   'Type_3': '> Ball Pythons',
#   'Sale_or_no': '[For Sale] superpastel lesser champagne female subadult',
#   'Price': '700',
#   'Keywords': ['around',
#    'gram',
#    'pounding',
#    'sm',
#    'md',
#    'rat',
#    'weekly',
#    'asking',
#    'plus',
#    'shipping']},
#  {'User_name': 'Bruce Tague',
#   'AD_name': 'Pastel Enchi Clown',
#   'Date': '11-25-2018, 02:24 PM',
#   'Type_1': '> Reptile & Amphibian - Classifieds',
#   'Type_2': '> Snakes For Sale/Wanteds',
#   'Type_3': '> Ball Pythons',
#   'Sale_or_no': '[For Sale] Pastel Enchi Clown',
#   'Price': '100',
#   'Keywords': ['pastel',
#    'enchi',
#    'clown',
#    'male',
#    'real',
#    'pretty',
#    'color',
#    'marking',
#    'breeding',
#    'came',
#    'het',
#    'blade',
#    'mellow',
#    'temperament',
#    'great',
#    'eater',
#    'eating',
#    'live',
#    'rat',
#    'crawler',
#    'hopper',
#    'mouse',
#    'weighs',
#    'gr',
#    'pm',
#    'additional',
#    'question',
#    'beagleman',
#    'cox',
#    'net',
#    'text',
#    'price',
#    'shipped',
#    'thanks',
#    'looking',
#    'bruce']},
#  {'User_name': 'asuitts',
#   'AD_name': 'Banana Ball Python',
#   'Date': '12-08-2018, 04:00 PM',
#   'Type_1': '> Reptile & Amphibian - Classifieds',
#   'Type_2': '> Snakes For Sale/Wanteds',
#   'Type_3': '> Ball Pythons',
#   'Sale_or_no': '[For Sale] Banana Ball Python',
#   'Price': '550',
#   'Keywords': ['beautiful',
#    'banana',
#    'ball',
#    'python',
#    'sale',
#    'includes',
#    'gallon',
#    'aquarium',
#    'accessory',
#    'inside',
#    'bedding',
#    'heating',
#    'lamp',
#    'uv',
#    'asking']},
#  {'User_name': 'adam_c',
#   'AD_name': '2018 BEL Male (poss GHI, Pastel, Pinstripe)',
#   'Date': '12-04-2018, 08:27 PM',
#   'Type_1': '> Reptile & Amphibian - Classifieds',
#   'Type_2': '> Snakes For Sale/Wanteds',
#   'Type_3': '> Ball Pythons',
#   'Sale_or_no': '[For Sale] 2018 BEL Male (poss GHI, Pastel, Pinstripe)',
#   'Price': '400',
#   'Keywords': ['beautiful',
#    'bel',
#    'male',
#    'available',
#    'come',
#    'ghi',
#    'pastel',
#    'lesser',
#    'mojave',
#    'pinstripe',
#    'pairing',
#    'telling',
#    'exactly',
#    'boy',
#    'could',
#    'hiding',
#    'grow',
#    'breed',
#    'prove',
#    'shipping',
#    'message',
#    'zip',
#    'code',
#    'quote',
#    'flexible',
#    'payment',
#    'plan',
#    'inquire',
#    'within']},
#  {'User_name': 'hleong',
#   'AD_name': 'Blue Eyed Leucistic Female',
#   'Date': '12-04-2018, 12:22 AM',
#   'Type_1': '> Reptile & Amphibian - Classifieds',
#   'Type_2': '> Snakes For Sale/Wanteds',
#   'Type_3': '> Ball Pythons',
#   'Sale_or_no': '[For Sale] Blue Eyed Leucistic Female',
#   'Price': '425',
#   'Keywords': ['blue',
#    'eyed',
#    'leucistic',
#    'female',
#    'established',
#    'feeding',
#    'fresh',
#    'killed',
#    'hopper',
#    'asking',
#    'plus',
#    'shipping',
#    'open',
#    'payment',
#    'plan',
#    'please',
#    'email',
#    'argus',
#    'att',
#    'net',
#    'call',
#    'interested',
#    'thank']},
#  {'User_name': 'hleong',
#   'AD_name': 'Super Pastel Pinstripe Mojave Banana Male',
#   'Date': '12-04-2018, 12:18 AM',
#   'Type_1': '> Reptile & Amphibian - Classifieds',
#   'Type_2': '> Snakes For Sale/Wanteds',
#   'Type_3': '> Ball Pythons',
#   'Sale_or_no': '[For Sale] Super Pastel Pinstripe Mojave Banana Male',
#   'Price': '350',
#   'Keywords': ['super',
#    'pastel',
#    'pinstripe',
#    'mojave',
#    'banana',
#    'male',
#    'well',
#    'established',
#    'feeding',
#    'fresh',
#    'killed',
#    'hopper',
#    'asking',
#    'plus',
#    'shipping',
#    'open',
#    'payment',
#    'plan',
#    'please',
#    'email',
#    'argus',
#    'att',
#    'net',
#    'call',
#    'interested',
#    'thank']},
#  {'User_name': 'hleong',
#   'AD_name': 'Pied Male and Female',
#   'Date': '12-04-2018, 12:15 AM',
#   'Type_1': '> Reptile & Amphibian - Classifieds',
#   'Type_2': '> Snakes For Sale/Wanteds',
#   'Type_3': '> Ball Pythons',
#   'Sale_or_no': '[For Sale] Pied Male and Female',
#   'Price': '275',
#   'Keywords': ['pied',
#    'male',
#    'female',
#    'well',
#    'established',
#    'feeding',
#    'fresh',
#    'killed',
#    'hopper',
#    'asking',
#    'plus',
#    'shipping',
#    'please',
#    'email',
#    'argus',
#    'att',
#    'net',
#    'call',
#    'interested',
#    'thank']},
#  {'User_name': 'hleong',
#   'AD_name': 'Super Blast Males and Females',
#   'Date': '12-03-2018, 11:26 PM',
#   'Type_1': '> Reptile & Amphibian - Classifieds',
#   'Type_2': '> Snakes For Sale/Wanteds',
#   'Type_3': '> Ball Pythons',
#   'Sale_or_no': '[For Sale] Super Blast Males and Females',
#   'Price': '125',
#   'Keywords': ['super',
#    'blast',
#    'male',
#    'three',
#    'female',
#    'well',
#    'established',
#    'feeding',
#    'fresh',
#    'killed',
#    'hopper',
#    'asking',
#    'plus',
#    'shipping',
#    'please',
#    'email',
#    'argus',
#    'att',
#    'net',
#    'call',
#    'interested',
#    'thank']},
#  {'User_name': 'hleong',
#   'AD_name': 'Super Pastel Female',
#   'Date': '12-03-2018, 02:50 AM',
#   'Type_1': '> Reptile & Amphibian - Classifieds',
#   'Type_2': '> Snakes For Sale/Wanteds',
#   'Type_3': '> Ball Pythons',
#   'Sale_or_no': '[For Sale] Super Pastel Female',
#   'Price': '100',
#   'Keywords': ['super',
#    'pastel',
#    'female',
#    'well',
#    'established',
#    'feeding',
#    'fresh',
#    'killed',
#    'hopper',
#    'pictured',
#    'sold',
#    'already',
#    'asking',
#    'plus',
#    'shipping',
#    'remaining',
#    'please',
#    'email',
#    'argus',
#    'att',
#    'net',
#    'call',
#    'interested',
#    'thank']},
#  {'User_name': 'hleong',
#   'AD_name': 'Lemon Blast Female',
#   'Date': '12-03-2018, 02:45 AM',
#   'Type_1': '> Reptile & Amphibian - Classifieds',
#   'Type_2': '> Snakes For Sale/Wanteds',
#   'Type_3': '> Ball Pythons',
#   'Sale_or_no': '[For Sale] Lemon Blast Female',
#   'Price': '100',
#   'Keywords': ['lemon',
#    'blast',
#    'female',
#    'well',
#    'established',
#    'feeding',
#    'fresh',
#    'killed',
#    'hopper',
#    'asking',
#    'plus',
#    'shipping',
#    'please',
#    'email',
#    'argus',
#    'att',
#    'net',
#    'call',
#    'interested',
#    'thank']},
#  {'User_name': 'hleong',
#   'AD_name': 'Killer Spinner Male and Female',
#   'Date': '12-03-2018, 02:38 AM',
#   'Type_1': '> Reptile & Amphibian - Classifieds',
#   'Type_2': '> Snakes For Sale/Wanteds',
#   'Type_3': '> Ball Pythons',
#   'Sale_or_no': '[For Sale] Killer Spinner Male and Female',
#   'Price': '150',
#   'Keywords': ['killer',
#    'spinner',
#    'male',
#    'female',
#    'well',
#    'established',
#    'feeding',
#    'fresh',
#    'killed',
#    'hopper',
#    'asking',
#    'plus',
#    'shipping',
#    'please',
#    'email',
#    'argus',
#    'att',
#    'net',
#    'call',
#    'interested',
#    'thank']},
#  {'User_name': 'hleong',
#   'AD_name': 'Firefly Male',
#   'Date': '12-03-2018, 02:34 AM',
#   'Type_1': '> Reptile & Amphibian - Classifieds',
#   'Type_2': '> Snakes For Sale/Wanteds',
#   'Type_3': '> Ball Pythons',
#   'Sale_or_no': '[For Sale] Firefly Male',
#   'Price': '150',
#   'Keywords': ['firefly',
#    'male',
#    'well',
#    'established',
#    'feeding',
#    'fresh',
#    'killed',
#    'hopper',
#    'asking',
#    'plus',
#    'shipping',
#    'please',
#    'email',
#    'argus',
#    'att',
#    'net',
#    'call',
#    'interested',
#    'thank']},
#  {'User_name': 'reptile_ryan',
#   'AD_name': '1.0 2018 Banana Pastel Het Genetic Stripe',
#   'Date': '12-03-2018, 02:32 AM',
#   'Type_1': '> Reptile & Amphibian - Classifieds',
#   'Type_2': '> Snakes For Sale/Wanteds',
#   'Type_3': '> Ball Pythons',
#   'Sale_or_no': '[For Sale] 1.0 2018 Banana Pastel Het Genetic Stripe',
#   'Price': '250',
#   'Keywords': ['great',
#    'looking',
#    'male',
#    'lot',
#    'potential',
#    'eating',
#    'small',
#    'rat',
#    'asking',
#    'cost',
#    'shipping',
#    'come',
#    'photo',
#    'genetics',
#    'guarantee',
#    'paperwork',
#    'thanks',
#    'let',
#    'know',
#    'answer',
#    'question']},
#  {'User_name': 'hleong',
#   'AD_name': 'Spinner Blast Male',
#   'Date': '12-03-2018, 02:32 AM',
#   'Type_1': '> Reptile & Amphibian - Classifieds',
#   'Type_2': '> Snakes For Sale/Wanteds',
#   'Type_3': '> Ball Pythons',
#   'Sale_or_no': '[For Sale] Spinner Blast Male',
#   'Price': '125',
#   'Keywords': ['spinner',
#    'blast',
#    'male',
#    'well',
#    'established',
#    'feeding',
#    'fresh',
#    'killed',
#    'hopper',
#    'asking',
#    'plus',
#    'shipping',
#    'please',
#    'email',
#    'argus',
#    'att',
#    'net',
#    'call',
#    'interested',
#    'thank']},
#  {'User_name': 'reptile_ryan',
#   'AD_name': '1.0 2018 Black Pastel Het Pied',
#   'Date': '12-03-2018, 02:28 AM',
#   'Type_1': '> Reptile & Amphibian - Classifieds',
#   'Type_2': '> Snakes For Sale/Wanteds',
#   'Type_3': '> Ball Pythons',
#   'Sale_or_no': '[For Sale] 1.0 2018 Black Pastel Het Pied',
#   'Price': '250',
#   'Keywords': ['great',
#    'looking',
#    'male',
#    'lot',
#    'potential',
#    'eating',
#    'rat',
#    'pup',
#    'asking',
#    'cost',
#    'shipping',
#    'come',
#    'photo',
#    'genetics',
#    'guarantee',
#    'paperwork',
#    'thanks',
#    'let',
#    'know',
#    'answer',
#    'question']},
#  {'User_name': 'hrennell',
#   'AD_name': '1.0 Pastel Champagne Ball Python',
#   'Date': '11-29-2018, 09:26 AM',
#   'Type_1': '> Reptile & Amphibian - Classifieds',
#   'Type_2': '> Snakes For Sale/Wanteds',
#   'Type_3': '> Ball Pythons',
#   'Sale_or_no': '1.0 Pastel Champagne Ball Python',
#   'Price': '250',
#   'Keywords': ['pastel',
#    'champagne',
#    'probable',
#    'leopard',
#    'ball',
#    'python',
#    'possible',
#    'double',
#    'het',
#    'ghost',
#    'pied',
#    'guy',
#    'hatched',
#    'well',
#    'started',
#    'currently',
#    'taking',
#    'mouse',
#    'without',
#    'hesitation',
#    'asking',
#    'plus',
#    'shipping',
#    'please',
#    'dm',
#    'information']},
#  {'User_name': 'snowgyre',
#   'AD_name': 'Female fire enchi mystic',
#   'Date': '10-28-2018, 09:46 AM',
#   'Type_1': '> Reptile & Amphibian - Classifieds',
#   'Type_2': '> Snakes For Sale/Wanteds',
#   'Type_3': '> Ball Pythons',
#   'Sale_or_no': '[For Sale] Female fire enchi mystic',
#   'Price': '300',
#   'Keywords': ['gorgeous',
#    'female',
#    'fire',
#    'enchi',
#    'mystic',
#    'available',
#    'plus',
#    'shipping',
#    'eating',
#    'combination',
#    'live',
#    'frozen',
#    'thawed',
#    'adult',
#    'mouse']},
#  {'User_name': 'snowgyre',
#   'AD_name': 'Male fire mystic',
#   'Date': '10-28-2018, 09:48 AM',
#   'Type_1': '> Reptile & Amphibian - Classifieds',
#   'Type_2': '> Snakes For Sale/Wanteds',
#   'Type_3': '> Ball Pythons',
#   'Sale_or_no': '[For Sale] Male fire mystic',
#   'Price': '150',
#   'Keywords': ['male', 'fire', 'mystic', 'available', 'plus', 'shipping']},
#  {'User_name': 'kimo2313',
#   'AD_name': '.1 Pastel Asphalt',
#   'Date': '10-29-2018, 01:50 PM',
#   'Type_1': '> Reptile & Amphibian - Classifieds',
#   'Type_2': '> Snakes For Sale/Wanteds',
#   'Type_3': '> Ball Pythons',
#   'Sale_or_no': '[For Sale] .1 Pastel Asphalt',
#   'Price': '350',
#   'Keywords': ['pastel',
#    'asphalt',
#    'female',
#    'available',
#    'eats',
#    'well',
#    'mouse',
#    'hopper',
#    'offered',
#    'anything',
#    'else',
#    'yet',
#    'minor',
#    'nip',
#    'back',
#    'affect',
#    'feeding',
#    'shed',
#    'plus',
#    'shipping']},
#  {'User_name': 'JoeRas',
#   'AD_name': 'Bongo Lesser Cinnamon',
#   'Date': '11-06-2018, 09:09 PM',
#   'Type_1': '> Reptile & Amphibian - Classifieds',
#   'Type_2': '> Snakes For Sale/Wanteds',
#   'Type_3': '> Ball Pythons',
#   'Sale_or_no': '[For Sale] Bongo Lesser Cinnamon',
#   'Price': '725',
#   'Keywords': ['female',
#    'bongo',
#    'lesser',
#    'cinnamon',
#    'gr',
#    'blue',
#    'eye',
#    'eating',
#    'small',
#    'fuzzy',
#    'live',
#    'rat',
#    'plus',
#    'shipping']},
#  {'User_name': 'alternaking',
#   'AD_name': 'Female pied',
#   'Date': '10-21-2018, 05:30 PM',
#   'Type_1': '> Reptile & Amphibian - Classifieds',
#   'Type_2': '> Snakes For Sale/Wanteds',
#   'Type_3': '> Ball Pythons',
#   'Sale_or_no': '[For Sale] Female pied',
#   'Price': '340',
#   'Keywords': ['slow', 'growing', 'female']},
#  {'User_name': 'JoeRas',
#   'AD_name': 'Leopard Champagne Pastel',
#   'Date': '11-03-2018, 02:40 AM',
#   'Type_1': '> Reptile & Amphibian - Classifieds',
#   'Type_2': '> Snakes For Sale/Wanteds',
#   'Type_3': '> Ball Pythons',
#   'Sale_or_no': '[For Sale] Leopard Champagne Pastel',
#   'Price': '725',
#   'Keywords': ['leopard',
#    'champagne',
#    'pastel',
#    'female',
#    'po',
#    'het',
#    'pied',
#    'gr',
#    'feeding',
#    'live',
#    'hopper',
#    'mouse',
#    'im',
#    'pretty',
#    'sure',
#    'prove',
#    'compared',
#    'others',
#    'clutch',
#    'pairing',
#    'plus',
#    'shipping',
#    'thanks',
#    'looking']},
#  {'User_name': 'alyjar',
#   'AD_name': 'Female Desert Ghost! $250 PRICED TO MOVE!!',
#   'Date': '11-01-2018, 10:36 PM',
#   'Type_1': '> Reptile & Amphibian - Classifieds',
#   'Type_2': '> Snakes For Sale/Wanteds',
#   'Type_3': '> Ball Pythons',
#   'Sale_or_no': 'Female Desert Ghost! $250 PRICED TO MOVE!!',
#   'Price': '250',
#   'Keywords': ['emergency',
#    'bill',
#    'need',
#    'pay',
#    'letting',
#    'female',
#    'desert',
#    'ghost',
#    'hatchling',
#    'go',
#    'almost',
#    'half',
#    'value',
#    'shipping',
#    'additional']},
#  ...]

# %%
dump_json(new_features,"zoo_data_nf2.json")
